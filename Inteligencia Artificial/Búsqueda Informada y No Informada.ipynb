# %%
from collections import deque
import heapq
import random
import math

# %%
# Definición del grafo con distancias entre las ciudades
grafo = {
    "International Falls": {"Grand Forks": 150, "Bemidji": 110, "Duluth": 200},
    "Grand Forks": {"International Falls": 150, "Fargo": 80, "Bemidji": 120},
    "Bemidji": {"International Falls": 110, "Grand Forks": 120, "St. Cloud": 140, "Duluth": 150},
    "Duluth": {"Bemidji": 150, "Minneapolis": 155, "International Falls": 200},
    "Fargo": {"Grand Forks": 80, "St. Cloud": 170, "Sioux Falls": 240},
    "St. Cloud": {"Bemidji": 140, "Fargo": 170, "Minneapolis": 65},
    "Minneapolis": {"St. Cloud": 65, "Duluth": 155, "LaCrosse": 150, "Rochester": 85, "Wausau": 180},
    "Wausau": {"Minneapolis": 180, "Green Bay": 100},
    "Green Bay": {"Wausau": 100, "Milwaukee": 120, "LaCrosse": 160},
    "LaCrosse": {"Minneapolis": 150, "Dubuque": 130, "Madison": 110, "Rochester": 70, "Green Bay": 160},
    "Rochester": {"Minneapolis": 85, "Dubuque": 130, "LaCrosse": 70, "Sioux Falls": 300},
    "Dubuque": {"Rochester": 130, "LaCrosse": 130, "Rockford": 80},
    "Rockford": {"Dubuque": 80, "Chicago": 90, "Madison": 70},
    "Chicago": {"Rockford": 90, "Milwaukee": 90},
    "Milwaukee": {"Chicago": 90, "Green Bay": 120, "Madison": 80},
    "Madison": {"Milwaukee": 80, "LaCrosse": 110, "Rockford": 70},
    "Sioux Falls": {"Fargo": 240, "Rochester": 300}
}

# %%
coordenadas = {
    "International Falls": (0, 10),
    "Grand Forks": (2, 8),
    "Bemidji": (4, 10),
    "Duluth": (7, 9),
    "Fargo": (3, 6),
    "St. Cloud": (6, 6),
    "Minneapolis": (8, 6),
    "Wausau": (10, 8),
    "Green Bay": (12, 8),
    "LaCrosse": (9, 5),
    "Rochester": (8, 4),
    "Dubuque": (8, 2),
    "Rockford": (9, 1),
    "Chicago": (10, 0),
    "Milwaukee": (11, 2),
    "Madison": (10, 4),
    "Sioux Falls": (1, 4)
}

# %%
def heuristica(ciudad_actual, ciudad_objetivo):
    x1, y1 = coordenadas[ciudad_actual]
    x2, y2 = coordenadas[ciudad_objetivo]
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# %%
def bfs(grafo, inicio, objetivo):
    visitados = set()
    cola = deque([[inicio]])
    
    while cola:
        camino = cola.popleft()
        nodo = camino[-1]
        
        if nodo in visitados:
            continue
        
        if nodo == objetivo:
            return camino
        
        visitados.add(nodo)
        
        for vecino in grafo.get(nodo, {}):
            nuevo_camino = list(camino)
            nuevo_camino.append(vecino)
            cola.append(nuevo_camino)
    
    return None

# %%
def dfs(grafo, inicio, objetivo, camino=None, visitados=None):
    if camino is None:
        camino = [inicio]
    if visitados is None:
        visitados = set()
    
    visitados.add(inicio)
    
    if inicio == objetivo:
        return camino
    
    for vecino in grafo.get(inicio, {}):
        if vecino not in visitados:
            resultado = dfs(grafo, vecino, objetivo, camino + [vecino], visitados)
            if resultado is not None:
                return resultado
    
    return None

# %%
def busqueda_avara(grafo, inicio, objetivo):
    open_list = []
    heapq.heappush(open_list, (heuristica(inicio, objetivo), inicio))
    came_from = {inicio: None}
    visited = set()

    while open_list:
        _, ciudad_actual = heapq.heappop(open_list)

        if ciudad_actual == objetivo:
            path = []
            while ciudad_actual is not None:
                path.append(ciudad_actual)
                ciudad_actual = came_from[ciudad_actual]
            return path[::-1]

        visited.add(ciudad_actual)

        for vecino in grafo[ciudad_actual]:
            if vecino not in visited:
                came_from[vecino] = ciudad_actual
                heapq.heappush(open_list, (heuristica(vecino, objetivo), vecino))

    return None

# %%
def a_estrella(grafo, inicio, objetivo):
    open_list = []
    heapq.heappush(open_list, (0, inicio))
    came_from = {}
    g_score = {ciudad: float('inf') for ciudad in grafo}
    g_score[inicio] = 0
    f_score = {ciudad: float('inf') for ciudad in grafo}
    f_score[inicio] = heuristica(inicio, objetivo)

    while open_list:
        _, ciudad_actual = heapq.heappop(open_list)

        if ciudad_actual == objetivo:
            path = []
            while ciudad_actual in came_from:
                path.append(ciudad_actual)
                ciudad_actual = came_from[ciudad_actual]
            path.append(inicio)
            return path[::-1]

        for vecino, coste in grafo[ciudad_actual].items():
            tentative_g_score = g_score[ciudad_actual] + coste

            if tentative_g_score < g_score[vecino]:
                came_from[vecino] = ciudad_actual
                g_score[vecino] = tentative_g_score
                f_score[vecino] = g_score[vecino] + heuristica(vecino, objetivo)
                heapq.heappush(open_list, (f_score[vecino], vecino))

    return None

# %%
def recocido_simulado(grafo, inicio, objetivo, temperatura=10000, tasa_enfriamiento=0.003):
    ciudad_actual = inicio
    mejor_ciudad = ciudad_actual
    mejor_distancia = heuristica(ciudad_actual, objetivo)
    ruta = [ciudad_actual]

    while temperatura > 1:
        vecino = random.choice(list(grafo[ciudad_actual].keys()))
        distancia_actual = heuristica(ciudad_actual, objetivo)
        distancia_vecino = heuristica(vecino, objetivo)

        if distancia_vecino < mejor_distancia:
            mejor_ciudad = vecino
            mejor_distancia = distancia_vecino
            ruta.append(vecino)

        if distancia_vecino < distancia_actual or random.uniform(0, 1) < math.exp((distancia_actual - distancia_vecino) / temperatura):
            ciudad_actual = vecino
            if ciudad_actual not in ruta:
                ruta.append(ciudad_actual)

        temperatura *= 1 - tasa_enfriamiento

    return ruta if ruta[-1] == objetivo else None

# %%
def hill_climbing(grafo, inicio, objetivo):
    ciudad_actual = inicio
    mejor_ciudad = ciudad_actual
    ruta = [ciudad_actual]

    while True:
        vecinos = list(grafo[ciudad_actual].keys())
        mejor_vecino = min(vecinos, key=lambda v: heuristica(v, objetivo))
        if heuristica(mejor_vecino, objetivo) >= heuristica(ciudad_actual, objetivo):
            break
        ciudad_actual = mejor_vecino
        ruta.append(ciudad_actual)

    return ruta if ruta[-1] == objetivo else None

# %%
def busqueda_tabu(grafo, inicio, objetivo, tabu_tam=5):
    tabu_list = deque(maxlen=tabu_tam)
    ciudad_actual = inicio
    mejor_ciudad = ciudad_actual
    ruta = [ciudad_actual]

    while ciudad_actual != objetivo:
        vecinos = list(grafo[ciudad_actual].keys())
        mejor_vecino = None

        for vecino in vecinos:
            if vecino in tabu_list:
                continue
            if mejor_vecino is None or heuristica(vecino, objetivo) < heuristica(mejor_vecino, objetivo):
                mejor_vecino = vecino

        if mejor_vecino is None:
            break

        tabu_list.append(ciudad_actual)
        ciudad_actual = mejor_vecino
        ruta.append(ciudad_actual)

        if heuristica(ciudad_actual, objetivo) < heuristica(mejor_ciudad, objetivo):
            mejor_ciudad = ciudad_actual

    return ruta if ruta[-1] == objetivo else None

# %%
inicio = input("Ingresa la ciudad de inicio: ")
objetivo = input("Ingresa la ciudad objetivo: ")

if inicio not in grafo or objetivo not in grafo:
    print("Una o ambas ciudades no están en el grafo.")
else:
    print("BFS:", bfs(grafo, inicio, objetivo))
    print("DFS:", dfs(grafo, inicio, objetivo))
    print("Búsqueda Avara:", busqueda_avara(grafo, inicio, objetivo))
    print("A*:", a_estrella(grafo, inicio, objetivo))
    print("Recocido Simulado:", recocido_simulado(grafo, inicio, objetivo))
    print("Hill Climbing:", hill_climbing(grafo, inicio, objetivo))
    print("Búsqueda Tabú:", busqueda_tabu(grafo, inicio, objetivo))
# Out:
# BFS: ['Rochester', 'Minneapolis', 'Wausau']
# DFS: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford', 'Chicago', 'Milwaukee', 'Green Bay', 'Wausau']
# Búsqueda Avara: ['Rochester', 'Minneapolis', 'Wausau']
# A*: ['Rochester', 'Minneapolis', 'Wausau']
# Recocido Simulado: None
# Hill Climbing: ['Rochester', 'Minneapolis', 'Wausau']
# Búsqueda Tabú: ['Rochester', 'Minneapolis', 'Wausau']

# %%
from collections import deque
import heapq
import random
import math

# Definición del grafo con distancias entre las ciudades
grafo = {
    "International Falls": {"Grand Forks": 150, "Bemidji": 110, "Duluth": 200},
    "Grand Forks": {"International Falls": 150, "Fargo": 80, "Bemidji": 120},
    "Bemidji": {"International Falls": 110, "Grand Forks": 120, "St. Cloud": 140, "Duluth": 150},
    "Duluth": {"Bemidji": 150, "Minneapolis": 155, "International Falls": 200},
    "Fargo": {"Grand Forks": 80, "St. Cloud": 170, "Sioux Falls": 240},
    "St. Cloud": {"Bemidji": 140, "Fargo": 170, "Minneapolis": 65},
    "Minneapolis": {"St. Cloud": 65, "Duluth": 155, "LaCrosse": 150, "Rochester": 85, "Wausau": 180},
    "Wausau": {"Minneapolis": 180, "Green Bay": 100},
    "Green Bay": {"Wausau": 100, "Milwaukee": 120, "LaCrosse": 160},
    "LaCrosse": {"Minneapolis": 150, "Dubuque": 130, "Madison": 110, "Rochester": 70, "Green Bay": 160},
    "Rochester": {"Minneapolis": 85, "Dubuque": 130, "LaCrosse": 70, "Sioux Falls": 300},
    "Dubuque": {"Rochester": 130, "LaCrosse": 130, "Rockford": 80},
    "Rockford": {"Dubuque": 80, "Chicago": 90, "Madison": 70},
    "Chicago": {"Rockford": 90, "Milwaukee": 90},
    "Milwaukee": {"Chicago": 90, "Green Bay": 120, "Madison": 80},
    "Madison": {"Milwaukee": 80, "LaCrosse": 110, "Rockford": 70},
    "Sioux Falls": {"Fargo": 240, "Rochester": 300}
}

coordenadas = {
    "International Falls": (0, 10),
    "Grand Forks": (2, 8),
    "Bemidji": (4, 10),
    "Duluth": (7, 9),
    "Fargo": (3, 6),
    "St. Cloud": (6, 6),
    "Minneapolis": (8, 6),
    "Wausau": (10, 8),
    "Green Bay": (12, 8),
    "LaCrosse": (9, 5),
    "Rochester": (8, 4),
    "Dubuque": (8, 2),
    "Rockford": (9, 1),
    "Chicago": (10, 0),
    "Milwaukee": (11, 2),
    "Madison": (10, 4),
    "Sioux Falls": (1, 4)
}

def heuristica(ciudad_actual, ciudad_objetivo):
    x1, y1 = coordenadas[ciudad_actual]
    x2, y2 = coordenadas[ciudad_objetivo]
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

def bfs(grafo, inicio, objetivo):
    print(f"Inicio BFS desde {inicio} hasta {objetivo}")
    visitados = set()
    cola = deque([[inicio]])
    
    while cola:
        camino = cola.popleft()
        nodo = camino[-1]
        
        print(f"Explorando nodo: {nodo}, Camino actual: {camino}")
        
        if nodo in visitados:
            print(f"Nodo {nodo} ya fue visitado.")
            continue
        
        if nodo == objetivo:
            print(f"Objetivo {objetivo} alcanzado.")
            return camino
        
        visitados.add(nodo)
        
        for vecino in grafo.get(nodo, {}):
            nuevo_camino = list(camino)
            nuevo_camino.append(vecino)
            print(f"Añadiendo camino: {nuevo_camino}")
            cola.append(nuevo_camino)
    
    print("No se encontró un camino.")
    return None

def dfs(grafo, inicio, objetivo, camino=None, visitados=None):
    if camino is None:
        camino = [inicio]
    if visitados is None:
        visitados = set()
    
    print(f"Explorando DFS desde {inicio}, Camino actual: {camino}")
    visitados.add(inicio)
    
    if inicio == objetivo:
        print(f"Objetivo {objetivo} alcanzado.")
        return camino
    
    for vecino in grafo.get(inicio, {}):
        if vecino not in visitados:
            print(f"Visitando vecino: {vecino}")
            resultado = dfs(grafo, vecino, objetivo, camino + [vecino], visitados)
            if resultado is not None:
                return resultado
    
    print(f"Retorno sin éxito desde {inicio}.")
    return None

def busqueda_avara(grafo, inicio, objetivo):
    print(f"Inicio Búsqueda Avara desde {inicio} hasta {objetivo}")
    open_list = []
    heapq.heappush(open_list, (heuristica(inicio, objetivo), inicio))
    came_from = {inicio: None}
    visited = set()

    while open_list:
        _, ciudad_actual = heapq.heappop(open_list)
        print(f"Explorando ciudad actual: {ciudad_actual}")

        if ciudad_actual == objetivo:
            path = []
            while ciudad_actual is not None:
                path.append(ciudad_actual)
                ciudad_actual = came_from[ciudad_actual]
            print(f"Objetivo alcanzado. Camino: {path[::-1]}")
            return path[::-1]

        visited.add(ciudad_actual)

        for vecino in grafo[ciudad_actual]:
            if vecino not in visited:
                came_from[vecino] = ciudad_actual
                print(f"Añadiendo {vecino} a la lista de exploración.")
                heapq.heappush(open_list, (heuristica(vecino, objetivo), vecino))

    print("No se encontró un camino.")
    return None

def a_estrella(grafo, inicio, objetivo):
    print(f"Inicio A* desde {inicio} hasta {objetivo}")
    open_list = []
    heapq.heappush(open_list, (0, inicio))
    came_from = {}
    g_score = {ciudad: float('inf') for ciudad in grafo}
    g_score[inicio] = 0
    f_score = {ciudad: float('inf') for ciudad in grafo}
    f_score[inicio] = heuristica(inicio, objetivo)

    while open_list:
        _, ciudad_actual = heapq.heappop(open_list)
        print(f"Explorando ciudad actual: {ciudad_actual}")

        if ciudad_actual == objetivo:
            path = []
            while ciudad_actual in came_from:
                path.append(ciudad_actual)
                ciudad_actual = came_from[ciudad_actual]
            path.append(inicio)
            print(f"Objetivo alcanzado. Camino: {path[::-1]}")
            return path[::-1]

        for vecino, coste in grafo[ciudad_actual].items():
            tentative_g_score = g_score[ciudad_actual] + coste

            if tentative_g_score < g_score[vecino]:
                came_from[vecino] = ciudad_actual
                g_score[vecino] = tentative_g_score
                f_score[vecino] = g_score[vecino] + heuristica(vecino, objetivo)
                print(f"Actualizando {vecino}, g_score: {tentative_g_score}, f_score: {f_score[vecino]}")
                heapq.heappush(open_list, (f_score[vecino], vecino))

    print("No se encontró un camino.")
    return None

def recocido_simulado(grafo, inicio, objetivo, temperatura=10000, tasa_enfriamiento=0.003):
    print(f"Inicio Recocido Simulado desde {inicio} hasta {objetivo}")
    ciudad_actual = inicio
    mejor_ciudad = ciudad_actual
    mejor_distancia = heuristica(ciudad_actual, objetivo)
    ruta = [ciudad_actual]

    while temperatura > 1:
        vecino = random.choice(list(grafo[ciudad_actual].keys()))
        distancia_actual = heuristica(ciudad_actual, objetivo)
        distancia_vecino = heuristica(vecino, objetivo)
        print(f"Temperatura: {temperatura}, Ciudad actual: {ciudad_actual}, Vecino elegido: {vecino}")

        if distancia_vecino < mejor_distancia:
            mejor_ciudad = vecino
            mejor_distancia = distancia_vecino
            ruta.append(vecino)
            print(f"Mejor distancia encontrada: {mejor_distancia} en {mejor_ciudad}")

        if distancia_vecino < distancia_actual or random.uniform(0, 1) < math.exp((distancia_actual - distancia_vecino) / temperatura):
            ciudad_actual = vecino
            if ciudad_actual not in ruta:
                ruta.append(ciudad_actual)

        temperatura *= 1 - tasa_enfriamiento

    print(f"Ruta final: {ruta}")
    return ruta if ruta[-1] == objetivo else None

def hill_climbing(grafo, inicio, objetivo):
    print(f"Inicio Hill Climbing desde {inicio} hasta {objetivo}")
    ciudad_actual = inicio
    ruta = [ciudad_actual]

    while True:
        vecinos = list(grafo[ciudad_actual].keys())
        mejor_vecino = min(vecinos, key=lambda v: heuristica(v, objetivo))
        print(f"Ciudad actual: {ciudad_actual}, Vecino seleccionado: {mejor_vecino}")

        if heuristica(mejor_vecino, objetivo) >= heuristica(ciudad_actual, objetivo):
            print("No se encontró un mejor vecino; se detiene la búsqueda.")
            break

        ciudad_actual = mejor_vecino
        ruta.append(ciudad_actual)

        if ciudad_actual == objetivo:
            print("Objetivo alcanzado.")
            return ruta

    print(f"Ruta final: {ruta}")
    return ruta if ruta[-1] == objetivo else None

def busqueda_tabu(grafo, inicio, objetivo, tabu_tam=5):
    print(f"Inicio Búsqueda Tabú desde {inicio} hasta {objetivo}")
    tabu_list = deque(maxlen=tabu_tam)
    ciudad_actual = inicio
    ruta = [ciudad_actual]

    while ciudad_actual != objetivo:
        vecinos = list(grafo[ciudad_actual].keys())
        mejor_vecino = None

        for vecino in vecinos:
            if vecino in tabu_list:
                print(f"Vecino {vecino} está en la lista Tabú y no será explorado.")
                continue
            if mejor_vecino is None or heuristica(vecino, objetivo) < heuristica(mejor_vecino, objetivo):
                mejor_vecino = vecino
                print(f"Nuevo mejor vecino encontrado: {mejor_vecino}")

        if mejor_vecino is None:
            print("No hay vecinos disponibles fuera de la lista Tabú.")
            break

        tabu_list.append(ciudad_actual)
        ciudad_actual = mejor_vecino
        ruta.append(ciudad_actual)
        print(f"Ciudad actual: {ciudad_actual}, Ruta: {ruta}")

        if ciudad_actual == objetivo:
            print("Objetivo alcanzado.")
            return ruta

    print(f"Ruta final: {ruta}")
    return ruta if ruta[-1] == objetivo else None

# Llamadas de ejemplo
inicio = input("Ingresa la ciudad de inicio: ")
objetivo = input("Ingresa la ciudad objetivo: ")

if inicio not in grafo or objetivo not in grafo:
    print("Una o ambas ciudades no están en el grafo.")
else:
    print("\nBFS:", bfs(grafo, inicio, objetivo), "\n")
    print("\nDFS:", dfs(grafo, inicio, objetivo), "\n")
    print("\nBúsqueda Avara:", busqueda_avara(grafo, inicio, objetivo), "\n")
    print("\nA*:", a_estrella(grafo, inicio, objetivo), "\n")
    print("\nRecocido Simulado:", recocido_simulado(grafo, inicio, objetivo), "\n")
    print("\nHill Climbing:", hill_climbing(grafo, inicio, objetivo), "\n")
    print("\nBúsqueda Tabú:", busqueda_tabu(grafo, inicio, objetivo), "\n")
# Out:
# Inicio BFS desde Rochester hasta Wausau
# Explorando nodo: Rochester, Camino actual: ['Rochester']
# Añadiendo camino: ['Rochester', 'Minneapolis']
# Añadiendo camino: ['Rochester', 'Dubuque']
# Añadiendo camino: ['Rochester', 'LaCrosse']
# Añadiendo camino: ['Rochester', 'Sioux Falls']
# Explorando nodo: Minneapolis, Camino actual: ['Rochester', 'Minneapolis']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'St. Cloud']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'Duluth']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'LaCrosse']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'Rochester']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'Wausau']
# Explorando nodo: Dubuque, Camino actual: ['Rochester', 'Dubuque']
# Añadiendo camino: ['Rochester', 'Dubuque', 'Rochester']
# Añadiendo camino: ['Rochester', 'Dubuque', 'LaCrosse']
# Añadiendo camino: ['Rochester', 'Dubuque', 'Rockford']
# Explorando nodo: LaCrosse, Camino actual: ['Rochester', 'LaCrosse']
# Añadiendo camino: ['Rochester', 'LaCrosse', 'Minneapolis']
# Añadiendo camino: ['Rochester', 'LaCrosse', 'Dubuque']
# Añadiendo camino: ['Rochester', 'LaCrosse', 'Madison']
# Añadiendo camino: ['Rochester', 'LaCrosse', 'Rochester']
# Añadiendo camino: ['Rochester', 'LaCrosse', 'Green Bay']
# Explorando nodo: Sioux Falls, Camino actual: ['Rochester', 'Sioux Falls']
# Añadiendo camino: ['Rochester', 'Sioux Falls', 'Fargo']
# Añadiendo camino: ['Rochester', 'Sioux Falls', 'Rochester']
# Explorando nodo: St. Cloud, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'St. Cloud', 'Fargo']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'St. Cloud', 'Minneapolis']
# Explorando nodo: Duluth, Camino actual: ['Rochester', 'Minneapolis', 'Duluth']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'Duluth', 'Bemidji']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'Duluth', 'Minneapolis']
# Añadiendo camino: ['Rochester', 'Minneapolis', 'Duluth', 'International Falls']
# Explorando nodo: LaCrosse, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse']
# Nodo LaCrosse ya fue visitado.
# Explorando nodo: Rochester, Camino actual: ['Rochester', 'Minneapolis', 'Rochester']
# Nodo Rochester ya fue visitado.
# Explorando nodo: Wausau, Camino actual: ['Rochester', 'Minneapolis', 'Wausau']
# Objetivo Wausau alcanzado.
#
# BFS: ['Rochester', 'Minneapolis', 'Wausau']
#
# Explorando DFS desde Rochester, Camino actual: ['Rochester']
# Visitando vecino: Minneapolis
# Explorando DFS desde Minneapolis, Camino actual: ['Rochester', 'Minneapolis']
# Visitando vecino: St. Cloud
# Explorando DFS desde St. Cloud, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud']
# Visitando vecino: Bemidji
# Explorando DFS desde Bemidji, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji']
# Visitando vecino: International Falls
# Explorando DFS desde International Falls, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji', 'International Falls']
# Visitando vecino: Grand Forks
# Explorando DFS desde Grand Forks, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji', 'International Falls', 'Grand Forks']
# Visitando vecino: Fargo
# Explorando DFS desde Fargo, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji', 'International Falls', 'Grand Forks', 'Fargo']
# Visitando vecino: Sioux Falls
# Explorando DFS desde Sioux Falls, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji', 'International Falls', 'Grand Forks', 'Fargo', 'Sioux Falls']
# Retorno sin éxito desde Sioux Falls.
# Retorno sin éxito desde Fargo.
# Retorno sin éxito desde Grand Forks.
# Visitando vecino: Duluth
# Explorando DFS desde Duluth, Camino actual: ['Rochester', 'Minneapolis', 'St. Cloud', 'Bemidji', 'International Falls', 'Duluth']
# Retorno sin éxito desde Duluth.
# Retorno sin éxito desde International Falls.
# Retorno sin éxito desde Bemidji.
# Retorno sin éxito desde St. Cloud.
# Visitando vecino: LaCrosse
# Explorando DFS desde LaCrosse, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse']
# Visitando vecino: Dubuque
# Explorando DFS desde Dubuque, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque']
# Visitando vecino: Rockford
# Explorando DFS desde Rockford, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford']
# Visitando vecino: Chicago
# Explorando DFS desde Chicago, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford', 'Chicago']
# Visitando vecino: Milwaukee
# Explorando DFS desde Milwaukee, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford', 'Chicago', 'Milwaukee']
# Visitando vecino: Green Bay
# Explorando DFS desde Green Bay, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford', 'Chicago', 'Milwaukee', 'Green Bay']
# Visitando vecino: Wausau
# Explorando DFS desde Wausau, Camino actual: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford', 'Chicago', 'Milwaukee', 'Green Bay', 'Wausau']
# Objetivo Wausau alcanzado.
#
# DFS: ['Rochester', 'Minneapolis', 'LaCrosse', 'Dubuque', 'Rockford', 'Chicago', 'Milwaukee', 'Green Bay', 'Wausau']
#
# Inicio Búsqueda Avara desde Rochester hasta Wausau
# Explorando ciudad actual: Rochester
# Añadiendo Minneapolis a la lista de exploración.
# Añadiendo Dubuque a la lista de exploración.
# Añadiendo LaCrosse a la lista de exploración.
# Añadiendo Sioux Falls a la lista de exploración.
# Explorando ciudad actual: Minneapolis
# Añadiendo St. Cloud a la lista de exploración.
# Añadiendo Duluth a la lista de exploración.
# Añadiendo LaCrosse a la lista de exploración.
# Añadiendo Wausau a la lista de exploración.
# Explorando ciudad actual: Wausau
# Objetivo alcanzado. Camino: ['Rochester', 'Minneapolis', 'Wausau']
#
# Búsqueda Avara: ['Rochester', 'Minneapolis', 'Wausau']
#
# Inicio A* desde Rochester hasta Wausau
# Explorando ciudad actual: Rochester
# Actualizando Minneapolis, g_score: 85, f_score: 87.82842712474618
# Actualizando Dubuque, g_score: 130, f_score: 136.32455532033677
# Actualizando LaCrosse, g_score: 70, f_score: 73.16227766016839
# Actualizando Sioux Falls, g_score: 300, f_score: 309.8488578017961
# Explorando ciudad actual: LaCrosse
# Actualizando Madison, g_score: 180, f_score: 184.0
# Actualizando Green Bay, g_score: 230, f_score: 232.0
# Explorando ciudad actual: Minneapolis
# Actualizando St. Cloud, g_score: 150, f_score: 154.47213595499957
# Actualizando Duluth, g_score: 240, f_score: 243.16227766016837
# Actualizando Wausau, g_score: 265, f_score: 265.0
# Explorando ciudad actual: Dubuque
# Actualizando Rockford, g_score: 210, f_score: 217.07106781186548
# Explorando ciudad actual: St. Cloud
# Actualizando Bemidji, g_score: 290, f_score: 296.32455532033674
# Actualizando Fargo, g_score: 320, f_score: 327.28010988928054
# Explorando ciudad actual: Madison
# Actualizando Milwaukee, g_score: 260, f_score: 266.0827625302982
# Explorando ciudad actual: Rockford
# Actualizando Chicago, g_score: 300, f_score: 308.0
# Explorando ciudad actual: Green Bay
# Explorando ciudad actual: Duluth
# Actualizando International Falls, g_score: 440, f_score: 450.1980390271856
# Explorando ciudad actual: Wausau
# Objetivo alcanzado. Camino: ['Rochester', 'Minneapolis', 'Wausau']
#
# A*: ['Rochester', 'Minneapolis', 'Wausau']
#
# Inicio Recocido Simulado desde Rochester hasta Wausau
# Temperatura: 10000, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 9970.0, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 9940.09, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Mejor distancia encontrada: 3.1622776601683795 en LaCrosse
# Temperatura: 9910.26973, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 9880.53892081, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 9850.89730404757, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 9821.344612135428, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Mejor distancia encontrada: 2.8284271247461903 en Minneapolis
# Temperatura: 9791.880578299022, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 9762.504936564124, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 9733.217421754433, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 9704.01776948917, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 9674.905716180703, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Mejor distancia encontrada: 0.0 en Wausau
# Temperatura: 9645.88099903216, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 9616.943356035064, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 9588.092525966958, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 9559.328248389058, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 9530.65026364389, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 9502.05831285296, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 9473.552137914401, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 9445.131481500657, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 9416.796087056155, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 9388.545698794986, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 9360.380061698601, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 9332.298921513506, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 9304.302024748966, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 9276.389118674719, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 9248.559951318695, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 9220.814271464738, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 9193.151828650343, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 9165.572373164392, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 9138.075656044899, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 9110.661429076765, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 9083.329444789535, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 9056.079456455167, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 9028.911218085801, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 9001.824484431543, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 8974.819010978248, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 8947.894553945313, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 8921.050870283476, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 8894.287717672625, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 8867.604854519608, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 8841.002039956049, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 8814.47903383618, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 8788.035596734671, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 8761.671489944467, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 8735.386475474634, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 8709.18031604821, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 8683.052775100066, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 8657.003616774766, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 8631.032605924442, Ciudad actual: Milwaukee, Vecino elegido: Madison
# Temperatura: 8605.139508106668, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 8579.324089582347, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 8553.5861173136, Ciudad actual: Madison, Vecino elegido: Milwaukee
# Temperatura: 8527.925358961658, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 8502.341582884774, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 8476.834558136119, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 8451.404054461711, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 8426.049842298326, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 8400.77169277143, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 8375.569377693117, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 8350.442669560038, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 8325.391341551358, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 8300.415167526704, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 8275.513922024124, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 8250.68738025805, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 8225.935318117276, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 8201.257512162923, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 8176.653739626435, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 8152.123778407556, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 8127.667407072333, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 8103.284404851116, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 8078.974551636563, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 8054.7376279816535, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 8030.573415097709, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 8006.481694852416, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 7982.462249767858, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 7958.514863018555, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 7934.639318429499, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 7910.8354004742105, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 7887.102894272788, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 7863.44158558997, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 7839.851260833199, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 7816.3317070507, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 7792.882711929548, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 7769.50406379376, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 7746.195551602379, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 7722.956964947572, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 7699.788094052728, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 7676.68872977057, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 7653.658663581258, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 7630.697687590515, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 7607.805594527743, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 7584.982177744159, Ciudad actual: St. Cloud, Vecino elegido: Bemidji
# Temperatura: 7562.227231210927, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 7539.5405495172945, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 7516.921927868742, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 7494.371162085136, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 7471.888048598881, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 7449.4723844530845, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 7427.123967299725, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 7404.842595397826, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 7382.628067611632, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 7360.4801834087975, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 7338.3987428585715, Ciudad actual: St. Cloud, Vecino elegido: Bemidji
# Temperatura: 7316.383546629996, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 7294.434395990106, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 7272.551092802136, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 7250.733439523729, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 7228.981239205158, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 7207.2942954875425, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 7185.6724126010795, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 7164.115395363277, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 7142.623049177187, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 7121.195180029655, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 7099.831594489566, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 7078.532099706097, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 7057.296503406978, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 7036.124613896757, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 7015.016240055067, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 6993.971191334902, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 6972.9892777608975, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 6952.070309927615, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 6931.2140989978325, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 6910.420456700839, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 6889.689195330737, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 6869.020127744745, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 6848.413067361511, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 6827.867828159427, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 6807.384224674948, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 6786.962072000923, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 6766.601185784921, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 6746.301382227566, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 6726.062478080883, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 6705.884290646641, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 6685.766637774701, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 6665.709337861377, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 6645.712209847793, Ciudad actual: Milwaukee, Vecino elegido: Madison
# Temperatura: 6625.775073218249, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 6605.897747998594, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 6586.080054754599, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 6566.321814590335, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 6546.622849146564, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 6526.982980599124, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 6507.402031657327, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 6487.879825562355, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 6468.416186085668, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 6449.010937527411, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 6429.663904714829, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 6410.3749130006845, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 6391.143788261683, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 6371.970356896898, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 6352.854445826208, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 6333.795882488729, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 6314.794494841263, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 6295.850111356739, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 6276.9625610226685, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 6258.131673339601, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 6239.357278319581, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 6220.639206484622, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 6201.977288865169, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 6183.371356998573, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 6164.821242927577, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 6146.326779198795, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 6127.8877988611985, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 6109.504135464615, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 6091.1756230582205, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 6072.902096189046, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 6054.683389900479, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 6036.519339730778, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 6018.409781711585, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 6000.354552366451, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 5982.353488709351, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 5964.406428243223, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 5946.513208958493, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 5928.673669331618, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 5910.887648323623, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 5893.154985378652, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 5875.475520422516, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 5857.849093861249, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 5840.2755465796645, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 5822.754719939925, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 5805.286455780105, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 5787.870596412765, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 5770.5069846235265, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 5753.1954636696555, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 5735.935877278646, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 5718.728069646811, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 5701.57188543787, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 5684.467169781557, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 5667.413768272212, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 5650.411526967396, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 5633.460292386493, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 5616.559911509334, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 5599.710231774806, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 5582.911101079481, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 5566.162367776243, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 5549.463880672914, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 5532.815489030895, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 5516.217042563802, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 5499.668391436111, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 5483.169386261803, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 5466.719878103017, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 5450.319718468709, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 5433.968759313303, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 5417.666853035363, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 5401.413852476257, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 5385.209610918828, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 5369.053982086071, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 5352.946820139813, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 5336.8879796793935, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 5320.877315740356, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 5304.914683793135, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 5288.999939741755, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 5273.13293992253, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 5257.313541102762, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 5241.541600479454, Ciudad actual: Milwaukee, Vecino elegido: Madison
# Temperatura: 5225.816975678016, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 5210.139524750982, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 5194.509106176729, Ciudad actual: Madison, Vecino elegido: Milwaukee
# Temperatura: 5178.925578858199, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 5163.388802121624, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 5147.89863571526, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 5132.454939808114, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 5117.05757498869, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 5101.706402263724, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 5086.401283056933, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 5071.1420792077615, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 5055.9286529701385, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 5040.760867011228, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 5025.638584410194, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 5010.561668656964, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 4995.529983650993, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 4980.54339370004, Ciudad actual: Bemidji, Vecino elegido: Grand Forks
# Temperatura: 4965.60176351894, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 4950.7049582283835, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 4935.8528433536985, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 4921.045284823637, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 4906.282148969166, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 4891.563302522259, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 4876.888612614692, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 4862.257946776847, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 4847.671172936517, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 4833.128159417707, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 4818.628774939454, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 4804.172888614636, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 4789.760369948792, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 4775.3910888389455, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 4761.064915572429, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 4746.781720825711, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 4732.541375663234, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 4718.343751536245, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 4704.188720281636, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 4690.076154120791, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 4676.005925658429, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 4661.977907881454, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 4647.99197415781, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 4634.047998235336, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 4620.14585424063, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 4606.285416677908, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 4592.466560427874, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 4578.6891607465905, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 4564.953093264351, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 4551.258233984558, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 4537.604459282604, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 4523.991645904756, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 4510.419670967042, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 4496.888411954141, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 4483.3977467182785, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 4469.947553478124, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 4456.53771081769, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 4443.168097685237, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 4429.838593392181, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 4416.549077612004, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 4403.299430379168, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 4390.089532088031, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 4376.919263491767, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 4363.788505701292, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 4350.697140184188, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 4337.645048763636, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 4324.632113617345, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 4311.658217276493, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 4298.723242624664, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 4285.82707289679, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 4272.969591678099, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 4260.150682903065, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 4247.370230854356, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 4234.628120161793, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 4221.924235801308, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 4209.258463093904, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 4196.630687704622, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 4184.040795641508, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 4171.488673254584, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 4158.97420723482, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 4146.497284613116, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 4134.057792759277, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 4121.655619380999, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 4109.290652522856, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 4096.962780565288, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 4084.6718922235923, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 4072.4178765469214, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 4060.2006229172807, Ciudad actual: Milwaukee, Vecino elegido: Madison
# Temperatura: 4048.020021048529, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 4035.8759609853837, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 4023.7683331024277, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 4011.6970281031204, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 3999.661937018811, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 3987.6629512077543, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 3975.699962354131, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 3963.7728624670685, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 3951.8815438796673, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 3940.0258992480285, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 3928.2058215502843, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 3916.4212040856337, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 3904.6719404733767, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 3892.9579246519565, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 3881.279050878001, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 3869.6352137253666, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 3858.0263080841905, Ciudad actual: Grand Forks, Vecino elegido: Fargo
# Temperatura: 3846.452229159938, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 3834.912872472458, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 3823.4081338550404, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 3811.937909453475, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 3800.502095725115, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 3789.1005894379396, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 3777.733287669626, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 3766.400087806617, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 3755.100887543197, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 3743.8355848805677, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 3732.604078125926, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 3721.4062658915486, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 3710.242047093874, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 3699.1113209525925, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 3688.013986989735, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 3676.949945028766, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 3665.9190951936794, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 3654.9213379080984, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 3643.9565738943743, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 3633.024704172691, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 3622.125630060173, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 3611.2592531699925, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 3600.4254754104822, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 3589.6241989842506, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 3578.8553263872977, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 3568.118760408136, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 3557.4144041269114, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 3546.742160914531, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 3536.1019344317874, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 3525.493628628492, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 3514.9171477426066, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 3504.3723962993786, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 3493.8592791104807, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 3483.3777012731493, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 3472.92756816933, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 3462.508785464822, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 3452.1212591084272, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 3441.764895331102, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 3431.4396006451084, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 3421.145281843173, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 3410.8818459976437, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 3400.6492004596507, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 3390.447252858272, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 3380.275911099697, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 3370.1350833663982, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 3360.024678116299, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 3349.9446040819503, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 3339.8947702697046, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 3329.8750859588954, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 3319.885460701019, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 3309.9258043189157, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 3299.996026905959, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 3290.096038825241, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 3280.225750708765, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 3270.385073456639, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 3260.573918236269, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 3250.79219648156, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 3241.0398198921152, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 3231.316700432439, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 3221.622750331142, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 3211.9578820801485, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 3202.322008433908, Ciudad actual: St. Cloud, Vecino elegido: Bemidji
# Temperatura: 3192.7150424086067, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 3183.1368972813807, Ciudad actual: St. Cloud, Vecino elegido: Bemidji
# Temperatura: 3173.5874865895366, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 3164.066724129768, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 3154.5745239573785, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 3145.1108003855065, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 3135.6754679843502, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 3126.2684415803974, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 3116.889636255656, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 3107.538967346889, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 3098.216350444848, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 3088.9217013935136, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 3079.654936289333, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 3070.415971480465, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 3061.2047235660234, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 3052.0211093953253, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 3042.8650460671392, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 3033.7364509289378, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 3024.6352415761507, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 3015.5613358514224, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 3006.5146518438683, Ciudad actual: Sioux Falls, Vecino elegido: Rochester
# Temperatura: 2997.495107888337, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 2988.502622564672, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 2979.537114696978, Ciudad actual: Fargo, Vecino elegido: St. Cloud
# Temperatura: 2970.598503352887, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 2961.686707842828, Ciudad actual: Fargo, Vecino elegido: Sioux Falls
# Temperatura: 2952.8016477192996, Ciudad actual: Sioux Falls, Vecino elegido: Fargo
# Temperatura: 2943.9432427761417, Ciudad actual: Fargo, Vecino elegido: Grand Forks
# Temperatura: 2935.111413047813, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 2926.3060788086696, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 2917.5271605722437, Ciudad actual: Grand Forks, Vecino elegido: Bemidji
# Temperatura: 2908.774579090527, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 2900.048255353255, Ciudad actual: St. Cloud, Vecino elegido: Bemidji
# Temperatura: 2891.3481105871956, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 2882.674066255434, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 2874.0260440566676, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 2865.4039659244977, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 2856.807754026724, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 2848.237330764644, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 2839.69261877235, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 2831.1735409160333, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 2822.680020293285, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 2814.211980232405, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 2805.769344291708, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 2797.352036258833, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 2788.9599801500563, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 2780.5931002096063, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 2772.2513209089775, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 2763.9345669462505, Ciudad actual: Bemidji, Vecino elegido: International Falls
# Temperatura: 2755.6427632454115, Ciudad actual: International Falls, Vecino elegido: Grand Forks
# Temperatura: 2747.375834955675, Ciudad actual: Grand Forks, Vecino elegido: International Falls
# Temperatura: 2739.1337074508083, Ciudad actual: International Falls, Vecino elegido: Duluth
# Temperatura: 2730.916306328456, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 2722.7235574094707, Ciudad actual: International Falls, Vecino elegido: Bemidji
# Temperatura: 2714.5553867372423, Ciudad actual: Bemidji, Vecino elegido: Duluth
# Temperatura: 2706.411720577031, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 2698.2924854153, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 2690.197607959054, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 2682.127015135177, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 2674.080634089771, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 2666.058392187502, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 2658.060217010939, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 2650.0860363599063, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 2642.1357782508267, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 2634.209370916074, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 2626.306742803326, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 2618.427822574916, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 2610.572539107191, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 2602.7408214898696, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 2594.9325990254, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 2587.1478012283237, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 2579.3863578246387, Ciudad actual: Rockford, Vecino elegido: Chicago
# Temperatura: 2571.6481987511647, Ciudad actual: Chicago, Vecino elegido: Milwaukee
# Temperatura: 2563.933254154911, Ciudad actual: Milwaukee, Vecino elegido: Chicago
# Temperatura: 2556.2414543924465, Ciudad actual: Chicago, Vecino elegido: Rockford
# Temperatura: 2548.572730029269, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 2540.9270118391814, Ciudad actual: Dubuque, Vecino elegido: Rockford
# Temperatura: 2533.304230803664, Ciudad actual: Rockford, Vecino elegido: Dubuque
# Temperatura: 2525.7043181112526, Ciudad actual: Dubuque, Vecino elegido: Rochester
# Temperatura: 2518.127205156919, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 2510.572823541448, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 2503.041105070824, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 2495.5319817556115, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 2488.0453858103447, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 2480.581249652914, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 2473.139505903955, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 2465.720087386243, Ciudad actual: Dubuque, Vecino elegido: LaCrosse
# Temperatura: 2458.3229271240843, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 2450.947958342712, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 2443.5951144676837, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 2436.2643291242807, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 2428.955536136908, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 2421.668669528497, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 2414.4036635199113, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 2407.1604525293515, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 2399.9389711717636, Ciudad actual: Milwaukee, Vecino elegido: Green Bay
# Temperatura: 2392.739154258248, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 2385.5609367954735, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 2378.404253985087, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 2371.269041223132, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 2364.1552340994626, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 2357.0627683971643, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# ...
# Temperatura: 1.7148529601049012, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 1.7097084012245864, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.7045792760209126, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.6994655381928498, Ciudad actual: Bemidji, Vecino elegido: St. Cloud
# Temperatura: 1.6943671415782713, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 1.6892840401535365, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 1.684216188033076, Ciudad actual: St. Cloud, Vecino elegido: Fargo
# Temperatura: 1.6791635394689768, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 1.6741260488505698, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 1.669103670704018, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 1.664096359691906, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 1.6591040706128304, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 1.654126758400992, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.649164378125789, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 1.6442168849914116, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.6392842343364373, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.634366381633428, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.6294632824885276, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.624574892641062, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 1.6197011679631388, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.6148420644592494, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.6099975382658716, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.605167545651074, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.6003520430141207, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.5955509868850783, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.590764333924423, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.5859920409226498, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.581234064799882, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.5764903626054823, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.5717608915176657, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.5670456088431128, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 1.5623444720165836, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.5576574386005337, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.552984466284732, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.548325512885878, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.5436805363472204, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.5390494947381788, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.5344323462539642, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.5298290492152022, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.5252395620675567, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.520663843381354, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 1.51610185185121, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 1.5115535462956562, Ciudad actual: Madison, Vecino elegido: Milwaukee
# Temperatura: 1.5070188856567692, Ciudad actual: Madison, Vecino elegido: Milwaukee
# Temperatura: 1.502497828999799, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 1.4979903355127997, Ciudad actual: Rockford, Vecino elegido: Madison
# Temperatura: 1.4934963645062613, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 1.4890158754127425, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 1.4845488277865042, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 1.4800951813031447, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 1.4756548957592353, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 1.4712279310719576, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 1.4668142472787418, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 1.4624138045369055, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.4580265631232947, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.4536524834339248, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.449291525983623, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 1.4449436514056722, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 1.440608820451455, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 1.4362869939901008, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.4319781330081305, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.4276821986091062, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.423399152013279, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.4191289545572392, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 1.4148715676935675, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 1.4106269529904867, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.4063950721315153, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.4021758869151206, Ciudad actual: Duluth, Vecino elegido: International Falls
# Temperatura: 1.3979693592543752, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.393775451176612, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.3895941248230823, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.3854253424486132, Ciudad actual: Rochester, Vecino elegido: LaCrosse
# Temperatura: 1.3812690664212672, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 1.3771252592220034, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 1.3729938834443374, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 1.3688749017940043, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 1.3647682770886223, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.3606739722573564, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.3565919503405843, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.3525221744895626, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.3484646079660938, Ciudad actual: Green Bay, Vecino elegido: Milwaukee
# Temperatura: 1.3444192141421956, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 1.3403859564997689, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 1.3363647986302696, Ciudad actual: LaCrosse, Vecino elegido: Dubuque
# Temperatura: 1.3323557042343788, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 1.3283586371216756, Ciudad actual: LaCrosse, Vecino elegido: Rochester
# Temperatura: 1.3243735612103105, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 1.3204004405266796, Ciudad actual: Rochester, Vecino elegido: Sioux Falls
# Temperatura: 1.3164392392050996, Ciudad actual: Rochester, Vecino elegido: Dubuque
# Temperatura: 1.3124899214874843, Ciudad actual: Rochester, Vecino elegido: Minneapolis
# Temperatura: 1.3085524517230218, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 1.3046267943678527, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.300712913984749, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.2968107752427949, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 1.2929203429170664, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.2890415818883152, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.2851744571426502, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 1.2813189337712223, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.2774749769699085, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.273642552038999, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.269821624382882, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.2660121595097333, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.262214123031204, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.2584274806621105, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.2546521982201242, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 1.2508882416254639, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 1.2471355769005874, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 1.2433941701698856, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 1.239663987659376, Ciudad actual: LaCrosse, Vecino elegido: Minneapolis
# Temperatura: 1.235944995696398, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.2322371607093088, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.2285404492271808, Ciudad actual: Duluth, Vecino elegido: Bemidji
# Temperatura: 1.2248548278794993, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.2211802633958608, Ciudad actual: Minneapolis, Vecino elegido: LaCrosse
# Temperatura: 1.2175167226056733, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 1.2138641724378563, Ciudad actual: Madison, Vecino elegido: Rockford
# Temperatura: 1.2102225799205426, Ciudad actual: Madison, Vecino elegido: LaCrosse
# Temperatura: 1.2065919121807809, Ciudad actual: LaCrosse, Vecino elegido: Madison
# Temperatura: 1.2029721364442385, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 1.1993632200349058, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 1.1957651303748011, Ciudad actual: Green Bay, Vecino elegido: LaCrosse
# Temperatura: 1.1921778349836767, Ciudad actual: LaCrosse, Vecino elegido: Green Bay
# Temperatura: 1.1886013014787256, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.1850354975742894, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.1814803910815665, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.177935949908322, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 1.174402142058597, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1708789356324212, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.167366298825524, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1638641999290473, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1603726073292602, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.1568914895072724, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1534208150387506, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1499605525936343, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1465106709358535, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.143071138923046, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.1396419255062769, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.136222999729758, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.1328143307305687, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.129415887738377, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1260276400751619, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1226495571549364, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.1192816084834716, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.1159237636580213, Ciudad actual: Green Bay, Vecino elegido: Wausau
# Temperatura: 1.1125759923670473, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.109238264389946, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.1059105495967763, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.102592817947986, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.099285039494142, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.0959871843756597, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0926992228225327, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.089421125154065, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.086152861778603, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.082894403193267, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0796457199836873, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.0764067828237363, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.073177562475265, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0699580297878393, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.0667481556984757, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.0635479112313804, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0603572674976862, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.057176195695193, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.0540046671081074, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.050842653106783, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0476901251474626, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0445470547720201, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.041413413607704, Ciudad actual: Minneapolis, Vecino elegido: St. Cloud
# Temperatura: 1.0382891733668809, Ciudad actual: St. Cloud, Vecino elegido: Minneapolis
# Temperatura: 1.0351743058467802, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.0320687829292399, Ciudad actual: Minneapolis, Vecino elegido: Rochester
# Temperatura: 1.028972576580452, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Temperatura: 1.0258856588507106, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0228080018741585, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.019739577868536, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0166803591349305, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.0136303180575257, Ciudad actual: Wausau, Vecino elegido: Green Bay
# Temperatura: 1.010589427103353, Ciudad actual: Wausau, Vecino elegido: Minneapolis
# Temperatura: 1.007557658822043, Ciudad actual: Minneapolis, Vecino elegido: Duluth
# Temperatura: 1.0045349858455768, Ciudad actual: Duluth, Vecino elegido: Minneapolis
# Temperatura: 1.00152138088804, Ciudad actual: Minneapolis, Vecino elegido: Wausau
# Ruta final: ['Rochester', 'Sioux Falls', 'LaCrosse', 'Dubuque', 'Minneapolis', 'Duluth', 'Bemidji', 'Wausau', 'St. Cloud', 'Fargo', 'Green Bay', 'Rockford', 'Madison', 'Chicago', 'Milwaukee', 'Grand Forks', 'International Falls']
#
# Recocido Simulado: None
#
# Inicio Hill Climbing desde Rochester hasta Wausau
# Ciudad actual: Rochester, Vecino seleccionado: Minneapolis
# Ciudad actual: Minneapolis, Vecino seleccionado: Wausau
# Objetivo alcanzado.
#
# Hill Climbing: ['Rochester', 'Minneapolis', 'Wausau']
#
# Inicio Búsqueda Tabú desde Rochester hasta Wausau
# Nuevo mejor vecino encontrado: Minneapolis
# Ciudad actual: Minneapolis, Ruta: ['Rochester', 'Minneapolis']
# Nuevo mejor vecino encontrado: St. Cloud
# Nuevo mejor vecino encontrado: Duluth
# Vecino Rochester está en la lista Tabú y no será explorado.
# Nuevo mejor vecino encontrado: Wausau
# Ciudad actual: Wausau, Ruta: ['Rochester', 'Minneapolis', 'Wausau']
# Objetivo alcanzado.
#
# Búsqueda Tabú: ['Rochester', 'Minneapolis', 'Wausau']
