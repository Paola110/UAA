# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import PIL 
from PIL import Image, ImageEnhance
import numpy as np


img = mpimg.imread("C:/Users/monts/OneDrive/Escritorio/UAA/Inteligencia Artificial/Recursos/cheque.jpg")
img = 1 - img

# Se crea un arreglo de ella para luego binarizarla 
img_array = np.array(img)
umbral = 127 #umbral para binarizacion 
binary_img = (img_array > umbral) * 255

fig, axes = plt.subplots(1,1, figsize=(10, 5))

axes.imshow(img)
axes.set_title("Original Image")
axes.axis('off')
# Out:
# (-0.5, 390.5, 143.5, -0.5)
